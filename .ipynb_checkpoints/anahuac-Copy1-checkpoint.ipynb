# %% [markdown]
# # MARATONA BEHIND THE CODE 2020
#
# ## DESAFIO 6 - ANAHUAC

# %% [markdown]
# ### Introducción

# %% [markdown]
# En este desafio, usted usará herramientas de IBM como Watson Studio (o Cloud Pak for Data) para construir un modelo baseado en Machine Learning capaz de preveer si un estudante irá continuar o abandonará su curso.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Installing Libs

# %%
# !pip install scikit-learn --upgrade
# Out:
# Requirement already up-to-date: scikit-learn in c:\users\wm_herrera\anaconda3\lib\site-packages (0.23.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\wm_herrera\anaconda3\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\wm_herrera\anaconda3\lib\site-packages (from scikit-learn) (0.16.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\wm_herrera\anaconda3\lib\site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\wm_herrera\anaconda3\lib\site-packages (from scikit-learn) (2.1.0)

# %%
# !pip install xgboost --upgrade
# Out:
# Requirement already up-to-date: xgboost in c:\users\wm_herrera\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\wm_herrera\anaconda3\lib\site-packages (from xgboost) (1.5.0)
# Requirement already satisfied, skipping upgrade: numpy in c:\users\wm_herrera\anaconda3\lib\site-packages (from xgboost) (1.17.0)

# %%
# !pip install seaborn --upgrade
# Out:
# Requirement already up-to-date: seaborn in c:\users\wm_herrera\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied, skipping upgrade: scipy>=1.0.1 in c:\users\wm_herrera\anaconda3\lib\site-packages (from seaborn) (1.5.0)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.1.2 in c:\users\wm_herrera\anaconda3\lib\site-packages (from seaborn) (3.2.2)
# Requirement already satisfied, skipping upgrade: pandas>=0.22.0 in c:\users\wm_herrera\anaconda3\lib\site-packages (from seaborn) (1.0.5)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\wm_herrera\anaconda3\lib\site-packages (from seaborn) (1.17.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\wm_herrera\anaconda3\lib\site-packages (from matplotlib>=2.1.2->seaborn) (1.2.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\wm_herrera\anaconda3\lib\site-packages (from matplotlib>=2.1.2->seaborn) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\wm_herrera\anaconda3\lib\site-packages (from matplotlib>=2.1.2->seaborn) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in c:\users\wm_herrera\anaconda3\lib\site-packages (from matplotlib>=2.1.2->seaborn) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\wm_herrera\anaconda3\lib\site-packages (from pandas>=0.22.0->seaborn) (2020.1)
# Requirement already satisfied, skipping upgrade: six in c:\users\wm_herrera\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.1.2->seaborn) (1.15.0)

# %% [markdown]
# <hr>

# %% [markdown]
# ## Loading the .csv dataset from GitHub

# %%
import pandas as pd

# %%
df_base_for_training = pd.read_csv(r'https://raw.githubusercontent.com/vanderlei-test/dataset2/master/datasets/ForTraining.csv')
df_base_for_training.head()
# Out:
#    studentId            reducido      ciclo Graduado
# 0    88588.0        Interv. Edu.  2019 - 08       No
# 1    81135.0           Educacion  2019 - 05       Si
# 2    80926.0  Direc. Estrat. Neg  2019 - 05       Si
# 3    82415.0               B. I.  2019 - 06       Si
# 4    90082.0       Est. Temprana  2019 - 08       No

# %% [markdown]
# Descripción: La primera tabla mostrada arriba tiene 4 columnas, 3 son features and el target: `Graduado` that has a binary values={Si, No}.
#
# Usted puede, y debe, usar mas data que esta disponible para construir su modelo. Los siguientes archivos .csv presentados:

# %%
df_orden_materias = pd.read_csv(r'https://raw.githubusercontent.com/vanderlei-test/dataset2/master/datasets/OrdenMaterias.csv')
df_orden_materias.head()
# Out:
#                   reducido  2017 - 03  2017 - 04  2017 - 05  2017 - 06  \
# 0  Act. Derecho Contratual  Sin clase  Sin clase  Sin clase  Sin clase
# 1                Adm. Emp.  Sin clase  Sin clase  Sin clase  Sin clase
# 2             Adm. Riesgos  Sin clase  Sin clase  Sin clase  Sin clase
# 3               Adm. Salud  Sin clase  Sin clase  Sin clase  Sin clase
# 4               Admon Fin.  Sin clase  Sin clase  Sin clase  Sin clase
#
#    2017 - 07  2017 - 08  2018 - 01  2018 - 02  2018 - 03  ...  \
# 0  Sin clase  Sin clase  Sin clase  Sin clase  Sin clase  ...
# 1  Sin clase  Sin clase  Sin clase  Sin clase  Sin clase  ...
# 2  Sin clase  Sin clase  Sin clase  Sin clase  Sin clase  ...
# 3  Sin clase  Sin clase  Sin clase  Sin clase  Sin clase  ...
# 4  Sin clase  Sin clase  Sin clase  Sin clase  Sin clase  ...
#
#                           2019 - 05  \
# 0                         Sin clase
# 1         Mercadotecnia Estratégica
# 2             Riesgos empresariales
# 3                  Calidad en salud
# 4  Decisión y Análisis de Inversión
#
#                                          2019 - 06  \
# 0                                        Sin clase
# 1           Contabilidad Financiera y Presupuestos
# 2           Contabilidad Financiera y Presupuestos
# 3           Contabilidad Financiera y Presupuestos
# 4  Decisión de Financiamiento y Pago de Dividendos
#
#                          2019 - 07                2019 - 08  \
# 0                        Sin clase                Sin clase
# 1         Administración de costos                Impuestos
# 2        Administración de riesgos    Evaluación de Riesgos
# 3         Administración de costos            Salud pública
# 4  Análisis de Estados Financieros  Estrategias de negocios
#
#                                            2020 - 01  \
# 0        Consentimiento y objeto digital contractual
# 1  Desafíos actuales en la Dirección del Capital ...
# 2                                 Toma de Decisiones
# 3                    Planeación estratégica en salud
# 4  Planeación Financiera y Administración del Cap...
#
#                                          2020 - 02  \
# 0  Métodos alternos de resolución de controversias
# 1                        Mercadotecnia Estratégica
# 2                            Riesgos empresariales
# 3                                 Calidad en salud
# 4                 Decisión y Análisis de Inversión
#
#                                          2020 - 03  \
# 0                  Nueva clasificación contractual
# 1           Contabilidad Financiera y Presupuestos
# 2           Contabilidad Financiera y Presupuestos
# 3           Contabilidad Financiera y Presupuestos
# 4  Decisión de Financiamiento y Pago de Dividendos
#
#                              2020 - 04                2020 - 05  \
# 0  Nuevo derecho probatorio documental   Contratos inteligentes
# 1             Administración de costos                Impuestos
# 2            Administración de riesgos    Evaluación de Riesgos
# 3      Planeación estratégica en salud            Salud pública
# 4      Análisis de Estados Financieros  Estrategias de negocios
#
#                                            2020 - 06
# 0        Consentimiento y objeto digital contractual
# 1  Desafíos actuales en la Dirección del Capital ...
# 2                                 Toma de Decisiones
# 3                    Planeación estratégica en salud
# 4  Planeación Financiera y Administración del Cap...
#
# [5 rows x 29 columns]

# %%
df_tabla_conexiones = pd.read_csv(r'https://raw.githubusercontent.com/vanderlei-test/dataset2/master/datasets/TablaConexiones.csv')
df_tabla_conexiones.head()
# Out:
#    studentId      ciclo  Dias_Conectado  Minutos_Promedio  Minutos_Total
# 0      45870  2017 - 03            10.0         76.957000         769.57
# 1      45898  2017 - 03            32.0        370.231250       11847.40
# 2      45905  2017 - 03            50.0        198.717400        9935.87
# 3      45931  2017 - 03            22.0        294.535909        6479.79
# 4      45933  2017 - 03            18.0        177.991667        3203.85

# %%
df_tabla_tareas = pd.read_csv(r'https://raw.githubusercontent.com/vanderlei-test/dataset2/master/datasets/TablaTareas.csv')
df_tabla_tareas.head()
# Out:
#    studentId      ciclo  Calificacion_Promedio  Tareas_Puntuales  \
# 0    81328.0  2019 - 05              99.000000              10.0
# 1    99206.0  2020 - 02              80.777500              10.0
# 2    94582.0  2020 - 01              79.666000              10.0
# 3    87564.0  2019 - 07               0.000000               0.0
# 4    87971.0  2019 - 08              36.363636               5.0
#
#    Tareas_No_Entregadas  Tareas_Retrasadas  Total_Tareas
# 0                   0.0                0.0          10.0
# 1                   2.0                0.0          12.0
# 2                   0.0                0.0          10.0
# 3                  15.0                0.0          15.0
# 4                   6.0                0.0          11.0

# %% [markdown]
# Overview del Dataset:
#
#     Disponibles para el participante, ecisten 4 tables cargas en DataFrames anteriormente:
#
#     **df_base_for_training**
#         - ``studentId``
#         ``reducido``
#         ``ciclo``
#         ``Graduado`` --> ¡LA VARIABLE OBJETIVO PARA CLASIFICACIÓN BINARIA!
#
#     **df_orden_materias**
#         ``reducido``
#         ``2017 - 03``
#         ``2017 - 04``
#         ``2017 - 05``
#         ``2017 - 06``
#         ``2017 - 07``
#         ``2017 - 08``
#         ``2018 - 01``
#         ``2018 - 02``
#         ``2018 - 03``
#         ``2018 - 04``
#         ``2018 - 05``
#         ``2018 - 06``
#         ``2018 - 07``
#         ``2018 - 08``
#         ``2019 - 01``
#         ``2019 - 02``
#         ``2019 - 03``
#         ``2019 - 04``
#         ``2019 - 05``
#         ``2019 - 06``
#         ``2019 - 07``
#         ``2019 - 08``
#         ``2020 - 01``
#         ``2020 - 02``
#         ``2020 - 03``
#         ``2020 - 04``
#         ``2020 - 05``
#         ``2020 - 06``
#
#     **df_tabla_conexiones**
#         - ``studentId``
#         ``ciclo``
#         ``Dias_Conectado``
#         ``Minutos_Promedio``
#         ``Minutos_Total``
#
#     **df_tabla_tareas**
#         - ``studentId``
#         ``ciclo``
#         ``Calificacion_Promedio``
#         ``Tareas_Puntuales``
#         ``Tareas_No_Entregadas``
#         ``Tareas_Retrasadas``
#         ``Total_Tareas``
#
# Observe que la variable ``studentId`` aparece en varias tablas.
#
# Usted puede combinar/merge estos datasets como usted desee.

# %%
print("Columnas en *df_base_for_training*:")
print(df_base_for_training.columns)

print("\Columnas en *df_orden_materias*:")
print(df_orden_materias.columns)

print("\Columnas en *df_tabla_conexiones*:")
print(df_tabla_conexiones.columns)

print("\Columnas en *df_tabla_tareas*:")
print(df_tabla_tareas.columns)
# Out:
# Columnas en *df_base_for_training*:
# Index(['studentId', 'reducido', 'ciclo', 'Graduado'], dtype='object')
# \Columnas en *df_orden_materias*:
# Index(['reducido', '2017 - 03', '2017 - 04', '2017 - 05', '2017 - 06',
#        '2017 - 07', '2017 - 08', '2018 - 01', '2018 - 02', '2018 - 03',
#        '2018 - 04', '2018 - 05', '2018 - 06', '2018 - 07', '2018 - 08',
#        '2019 - 01', '2019 - 02', '2019 - 03', '2019 - 04', '2019 - 05',
#        '2019 - 06', '2019 - 07', '2019 - 08', '2020 - 01', '2020 - 02',
#        '2020 - 03', '2020 - 04', '2020 - 05', '2020 - 06'],
#       dtype='object')
# \Columnas en *df_tabla_conexiones*:
# Index(['studentId', 'ciclo', 'Dias_Conectado', 'Minutos_Promedio',
#        'Minutos_Total'],
#       dtype='object')
# \Columnas en *df_tabla_tareas*:
# Index(['studentId', 'ciclo', 'Calificacion_Promedio', 'Tareas_Puntuales',
#        'Tareas_No_Entregadas', 'Tareas_Retrasadas', 'Total_Tareas'],
#       dtype='object')

# %% [markdown]
# #### ¡ATENCIÓN! La columna **target** es  ``Graduado``, presente en el DataFrame "df_base_for_training".

# %% [markdown]
# <hr>

# %% [markdown]
# ## Uniendo DataFrames en Pandas
#
# Documentación oficial para Pandas 1.1.0: https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# Como un **ejemplo** de como usar Pandas, camos a unir/merge la información de las tablas "df_base_for_training" y "df_tabla_tareas" a traves de la llave ``studentId``.
#
# Usted puee editar el dataframes manualmente si lo prefiere, usando Microsoft Excel u otros lenguajes. Recuerde insertar la data procesada en IBM Cloud Pak for Data para que pueda entrenar su modelo.

# %%
df_base_for_training.tail()
# Out:
#       studentId           reducido      ciclo Graduado
# 2495    89685.0  Estrat. Comercial  2019 - 08       No
# 2496    77590.0      Crianza Hijos  2019 - 06       Si
# 2497    57623.0      Mercadotecnia  2018 - 02       Si
# 2498    50018.0  Lider. Inst. Edu.  2017 - 05       No
# 2499    88250.0   Prof. Deportiva.  2019 - 08       No

# %%
df_tabla_tareas.tail()
# Out:
#       studentId      ciclo  Calificacion_Promedio  Tareas_Puntuales  \
# 6293    80467.0  2019 - 05              20.000000               1.0
# 6294    80249.0  2019 - 05              50.600000               3.0
# 6295    85857.0  2019 - 07              81.428571              13.0
# 6296    98880.0  2020 - 02              91.212727              11.0
# 6297    71859.0  2019 - 02              87.333000              10.0
#
#       Tareas_No_Entregadas  Tareas_Retrasadas  Total_Tareas
# 6293                   4.0                0.0           5.0
# 6294                   2.0                0.0           5.0
# 6295                   1.0                0.0          14.0
# 6296                   0.0                0.0          11.0
# 6297                   0.0                0.0          10.0

# %%
# El resultado de esta celda sera la union de los dos anteriores dataframes
# usando la columna ``studentId`` como llave.

df = pd.merge(
    df_base_for_training, df_tabla_tareas, how='inner',
    on=None, left_on=['studentId', 'ciclo'], right_on=['studentId', 'ciclo'],
    left_index=False, right_index=False, sort=True,
    suffixes=('_x', '_y'), copy=True, indicator=False,
    validate=None
)
df.describe()
# Out:
#           studentId  Calificacion_Promedio  Tareas_Puntuales  \
# count   2500.000000            2500.000000       2500.000000
# mean   76826.320800              71.446212          8.826800
# std    10531.545832              28.357020          4.105063
# min    45898.000000               0.000000          0.000000
# 25%    71813.250000              65.667000          7.000000
# 50%    79062.500000              82.777083          9.000000
# 75%    84517.250000              90.748141         11.000000
# max    91346.000000             100.000000         29.000000
#
#        Tareas_No_Entregadas  Tareas_Retrasadas  Total_Tareas
# count           2500.000000        2500.000000   2500.000000
# mean               2.165200           0.182800     11.174800
# std                3.795428           0.651732      3.232031
# min                0.000000           0.000000      5.000000
# 25%                0.000000           0.000000      9.000000
# 50%                0.000000           0.000000     10.000000
# 75%                2.000000           0.000000     13.000000
# max               34.000000           9.000000     34.000000

# %%
dfr = pd.merge(
    df, df_tabla_conexiones, how='inner',
    on=None, left_on=['studentId', 'ciclo'], right_on=['studentId', 'ciclo'],
    left_index=False, right_index=False, sort=True,
    suffixes=('_x', '_y'), copy=True, indicator=False,
    validate=None
)
dfr.describe()
# Out:
#           studentId  Calificacion_Promedio  Tareas_Puntuales  \
# count   2500.000000            2500.000000       2500.000000
# mean   76826.320800              71.446212          8.826800
# std    10531.545832              28.357020          4.105063
# min    45898.000000               0.000000          0.000000
# 25%    71813.250000              65.667000          7.000000
# 50%    79062.500000              82.777083          9.000000
# 75%    84517.250000              90.748141         11.000000
# max    91346.000000             100.000000         29.000000
#
#        Tareas_No_Entregadas  Tareas_Retrasadas  Total_Tareas  Dias_Conectado  \
# count           2500.000000        2500.000000   2500.000000     2500.000000
# mean               2.165200           0.182800     11.174800       49.085600
# std                3.795428           0.651732      3.232031       33.072075
# min                0.000000           0.000000      5.000000        1.000000
# 25%                0.000000           0.000000      9.000000       23.000000
# 50%                0.000000           0.000000     10.000000       42.000000
# 75%                2.000000           0.000000     13.000000       71.000000
# max               34.000000           9.000000     34.000000      199.000000
#
#        Minutos_Promedio  Minutos_Total
# count       2500.000000    2500.000000
# mean         259.036880   12190.417404
# std          145.739734    9760.184061
# min            0.000000       0.000000
# 25%          158.080298    5080.940000
# 50%          231.097917   10019.110000
# 75%          332.742845   16644.392500
# max         1173.203571  107245.770000

# %%
# Información acerca de las columnas del dataset unido
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 0 to 2499
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   studentId              2500 non-null   float64
#  1   reducido               2500 non-null   object
#  2   ciclo                  2500 non-null   object
#  3   Graduado               2500 non-null   object
#  4   Calificacion_Promedio  2500 non-null   float64
#  5   Tareas_Puntuales       2500 non-null   float64
#  6   Tareas_No_Entregadas   2500 non-null   float64
#  7   Tareas_Retrasadas      2500 non-null   float64
#  8   Total_Tareas           2500 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 195.3+ KB

# %%
dfr.info()
df=dfr
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 0 to 2499
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   studentId              2500 non-null   float64
#  1   reducido               2500 non-null   object
#  2   ciclo                  2500 non-null   object
#  3   Graduado               2500 non-null   object
#  4   Calificacion_Promedio  2500 non-null   float64
#  5   Tareas_Puntuales       2500 non-null   float64
#  6   Tareas_No_Entregadas   2500 non-null   float64
#  7   Tareas_Retrasadas      2500 non-null   float64
#  8   Total_Tareas           2500 non-null   float64
#  9   Dias_Conectado         2500 non-null   float64
#  10  Minutos_Promedio       2500 non-null   float64
#  11  Minutos_Total          2500 non-null   float64
# dtypes: float64(9), object(3)
# memory usage: 253.9+ KB

# %%
df = df.drop(df[df['studentId']==60542].index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2499 entries, 0 to 2499
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   studentId              2499 non-null   float64
#  1   reducido               2499 non-null   object
#  2   ciclo                  2499 non-null   object
#  3   Graduado               2499 non-null   object
#  4   Calificacion_Promedio  2499 non-null   float64
#  5   Tareas_Puntuales       2499 non-null   float64
#  6   Tareas_No_Entregadas   2499 non-null   float64
#  7   Tareas_Retrasadas      2499 non-null   float64
#  8   Total_Tareas           2499 non-null   float64
#  9   Dias_Conectado         2499 non-null   float64
#  10  Minutos_Promedio       2499 non-null   float64
#  11  Minutos_Total          2499 non-null   float64
# dtypes: float64(9), object(3)
# memory usage: 253.8+ KB

# %%
print(df_orden_materias.columns)

df_orden_materias.head()
# Out:
# Index(['reducido', '2017 - 03', '2017 - 04', '2017 - 05', '2017 - 06',
#        '2017 - 07', '2017 - 08', '2018 - 01', '2018 - 02', '2018 - 03',
#        '2018 - 04', '2018 - 05', '2018 - 06', '2018 - 07', '2018 - 08',
#        '2019 - 01', '2019 - 02', '2019 - 03', '2019 - 04', '2019 - 05',
#        '2019 - 06', '2019 - 07', '2019 - 08', '2020 - 01', '2020 - 02',
#        '2020 - 03', '2020 - 04', '2020 - 05', '2020 - 06'],
#       dtype='object')
#                   reducido  2017 - 03  2017 - 04  2017 - 05  2017 - 06  \
# 0  Act. Derecho Contratual  Sin clase  Sin clase  Sin clase  Sin clase
# 1                Adm. Emp.  Sin clase  Sin clase  Sin clase  Sin clase
# 2             Adm. Riesgos  Sin clase  Sin clase  Sin clase  Sin clase
# 3               Adm. Salud  Sin clase  Sin clase  Sin clase  Sin clase
# 4               Admon Fin.  Sin clase  Sin clase  Sin clase  Sin clase
#
#    2017 - 07  2017 - 08  2018 - 01  2018 - 02  2018 - 03  ...  \
# 0  Sin clase  Sin clase  Sin clase  Sin clase  Sin clase  ...
# 1  Sin clase  Sin clase  Sin clase  Sin clase  Sin clase  ...
# 2  Sin clase  Sin clase  Sin clase  Sin clase  Sin clase  ...
# 3  Sin clase  Sin clase  Sin clase  Sin clase  Sin clase  ...
# 4  Sin clase  Sin clase  Sin clase  Sin clase  Sin clase  ...
#
#                           2019 - 05  \
# 0                         Sin clase
# 1         Mercadotecnia Estratégica
# 2             Riesgos empresariales
# 3                  Calidad en salud
# 4  Decisión y Análisis de Inversión
#
#                                          2019 - 06  \
# 0                                        Sin clase
# 1           Contabilidad Financiera y Presupuestos
# 2           Contabilidad Financiera y Presupuestos
# 3           Contabilidad Financiera y Presupuestos
# 4  Decisión de Financiamiento y Pago de Dividendos
#
#                          2019 - 07                2019 - 08  \
# 0                        Sin clase                Sin clase
# 1         Administración de costos                Impuestos
# 2        Administración de riesgos    Evaluación de Riesgos
# 3         Administración de costos            Salud pública
# 4  Análisis de Estados Financieros  Estrategias de negocios
#
#                                            2020 - 01  \
# 0        Consentimiento y objeto digital contractual
# 1  Desafíos actuales en la Dirección del Capital ...
# 2                                 Toma de Decisiones
# 3                    Planeación estratégica en salud
# 4  Planeación Financiera y Administración del Cap...
#
#                                          2020 - 02  \
# 0  Métodos alternos de resolución de controversias
# 1                        Mercadotecnia Estratégica
# 2                            Riesgos empresariales
# 3                                 Calidad en salud
# 4                 Decisión y Análisis de Inversión
#
#                                          2020 - 03  \
# 0                  Nueva clasificación contractual
# 1           Contabilidad Financiera y Presupuestos
# 2           Contabilidad Financiera y Presupuestos
# 3           Contabilidad Financiera y Presupuestos
# 4  Decisión de Financiamiento y Pago de Dividendos
#
#                              2020 - 04                2020 - 05  \
# 0  Nuevo derecho probatorio documental   Contratos inteligentes
# 1             Administración de costos                Impuestos
# 2            Administración de riesgos    Evaluación de Riesgos
# 3      Planeación estratégica en salud            Salud pública
# 4      Análisis de Estados Financieros  Estrategias de negocios
#
#                                            2020 - 06
# 0        Consentimiento y objeto digital contractual
# 1  Desafíos actuales en la Dirección del Capital ...
# 2                                 Toma de Decisiones
# 3                    Planeación estratégica en salud
# 4  Planeación Financiera y Administración del Cap...
#
# [5 rows x 29 columns]

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

profile = ProfileReport(df, title="Pandas Profiling Report")
#profile

# %% [markdown]
# De la información de arriba ud puede observar que hay valores Null/NaN en algunas de las columnas.
#
# Para que nuestro modelo quede bien entrenado necesitamos procesar estos valores nulos de una forma adecuada.
#
# Usted escogera la mejor estrategia como parte del desafío, pero en la siguiente celda encuentra un **ejemplo** the como puede hacer este procesamiento usanto la libreria *scikit-learn*.
#
# <hr>

# %% [markdown]
# ## Pre-procesando el dataset antes de entrenar

# %% [markdown]
# ### Borrando finlas con valores NaN

# %% [markdown]
# Usando el metodo Pandas DataFrame.dropna() usted puede remover todas las filas que estan indefinidas para la columna ``Graduado``.
#
# Docs: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html

# %%
# Visualizando los datos faltantes del dataset antes de la primera transformación (df_data_2)
print("Valores nulos antes de la transformación DropNA: \n\n{}\n".format(df.isnull().sum(axis = 0)))
# Out:
# Valores nulos antes de la transformación DropNA:
#
# studentId                0
# reducido                 0
# ciclo                    0
# Graduado                 0
# Calificacion_Promedio    0
# Tareas_Puntuales         0
# Tareas_No_Entregadas     0
# Tareas_Retrasadas        0
# Total_Tareas             0
# Dias_Conectado           0
# Minutos_Promedio         0
# Minutos_Total            0
# dtype: int64

# %%
# Aplicando la función para borrar todas las filas con valor NaN en la columna ``Graduado``:
df2 = df.dropna(axis='index', how='any', subset=['Graduado'])

# %%
# Visualizando los datos faltantes del dataset antes de la primera transformación (SimpleImputer) (df_data_3)
print("Valores nulos antes de la transformación SimpleImputer: \n\n{}\n".format(df2.isnull().sum(axis = 0)))
# Out:
# Valores nulos antes de la transformación SimpleImputer:
#
# studentId                0
# reducido                 0
# ciclo                    0
# Graduado                 0
# Calificacion_Promedio    0
# Tareas_Puntuales         0
# Tareas_No_Entregadas     0
# Tareas_Retrasadas        0
# Total_Tareas             0
# Dias_Conectado           0
# Minutos_Promedio         0
# Minutos_Total            0
# dtype: int64

# %% [markdown]
# ### Procesando valores NaN con SimpleImputer de sklearn
#
# Para los otros valores NaN vamos a usar como **ejemplo** la sustitución por la constante 0.
#
# Usted puede escoger cualquier estrategia que crea que es la mejor para esto :)
#
# Docs: https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html?highlight=simpleimputer#sklearn.impute.SimpleImputer

# %%
from sklearn.impute import SimpleImputer
import numpy as np


# Creando un objeto ``SimpleImputer``
impute_zeros = SimpleImputer(
    missing_values=np.nan,  # Los valores faltantes son de tipo ``np.nan`` (estandar Pandas)
    strategy='constant',  # La estrategia escogida es reemplazar por una constante
    fill_value=0,  # La constante que será usada para reemmplazar los valores faltantes es un int64=0.
    verbose=0,
    copy=True
)

# %%
# Visualizando los datos faltantes del dataset antes de la segunda transformación (df_data_2)
print("Valores nulos antes de transformación SimpleImputer: \n\n{}\n".format(df2.isnull().sum(axis = 0)))

# Aplicar la transformación ``SimpleImputer`` en el conjunto de datos base
impute_zeros.fit(X=df)

# Reconstrucción del nuevo DataFrame Pandas (df_data_3)
df = pd.DataFrame.from_records(
    data=impute_zeros.transform(
        X=df
    ),  # El resultado SimpleImputer.transform(<<pandas dataframe>>) es una lista de listas
    columns=df.columns  # Las columnas originals deben ser conservadas en esta transformación
)

# Visualizndo los datos faltantes del dataset 
print("Valores nulos del dataset despues de la transformación SimpleImputer: \n\n{}\n".format(df.isnull().sum(axis = 0)))
# Out:
# Valores nulos antes de transformación SimpleImputer:
#
# studentId                0
# reducido                 0
# ciclo                    0
# Graduado                 0
# Calificacion_Promedio    0
# Tareas_Puntuales         0
# Tareas_No_Entregadas     0
# Tareas_Retrasadas        0
# Total_Tareas             0
# Dias_Conectado           0
# Minutos_Promedio         0
# Minutos_Total            0
# dtype: int64
#
# Valores nulos del dataset despues de la transformación SimpleImputer:
#
# studentId                0
# reducido                 0
# ciclo                    0
# Graduado                 0
# Calificacion_Promedio    0
# Tareas_Puntuales         0
# Tareas_No_Entregadas     0
# Tareas_Retrasadas        0
# Total_Tareas             0
# Dias_Conectado           0
# Minutos_Promedio         0
# Minutos_Total            0
# dtype: int64

# %% [markdown]
# ### Eliminando columnas no desadas
#
# Vamos a **demostrar** acontinuación como usar el metodo DataFrame.drop().
#
# Docs: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html

# %%
df.tail()
# Out:
#       studentId         reducido      ciclo Graduado  Calificacion_Promedio  \
# 2494    91320.0        Adm. Emp.  2019 - 08       No              71.818182
# 2495    91330.0            I. A.  2019 - 08       Si              81.333333
# 2496    91331.0       Gest. Esc.  2019 - 08       No              73.333333
# 2497    91335.0       Gest. Esc.  2019 - 08       Si              85.185556
# 2498    91346.0  Psicopat. Adol.  2019 - 08       No              80.159333
#
#       Tareas_Puntuales  Tareas_No_Entregadas  Tareas_Retrasadas  Total_Tareas  \
# 2494               9.0                   2.0                0.0          11.0
# 2495              15.0                   0.0                0.0          15.0
# 2496               9.0                   0.0                0.0           9.0
# 2497               9.0                   0.0                0.0           9.0
# 2498              15.0                   0.0                0.0          15.0
#
#       Dias_Conectado  Minutos_Promedio  Minutos_Total
# 2494            21.0        468.019048        9828.40
# 2495            90.0        431.348000       38821.32
# 2496            27.0        171.675926        4635.25
# 2497           102.0        256.105686       26122.78
# 2498            26.0        230.841538        6001.88

# %%
def getMateria(df,ciclo,reducido): 
    try:
      return df[df['reducido']==reducido][ciclo].values[0]
    except:
      return 'Sin clase'

for index, row in df.iterrows():
    df.at[index,'materia'] =getMateria(df_orden_materias,row.ciclo,row.reducido)
df
# Out:
#       studentId             reducido      ciclo Graduado  \
# 0       45898.0        Mercadotecnia  2017 - 03       Si
# 1       45905.0           Intro. Fin  2017 - 03       No
# 2       45931.0         Direc. Proy.  2017 - 03       No
# 3       46063.0  Comp. Dig. Docentes  2017 - 03       Si
# 4       46106.0           Gest. Esc.  2017 - 03       Si
# ...         ...                  ...        ...      ...
# 2494    91320.0            Adm. Emp.  2019 - 08       No
# 2495    91330.0                I. A.  2019 - 08       Si
# 2496    91331.0           Gest. Esc.  2019 - 08       No
# 2497    91335.0           Gest. Esc.  2019 - 08       Si
# 2498    91346.0      Psicopat. Adol.  2019 - 08       No
#
#       Calificacion_Promedio  Tareas_Puntuales  Tareas_No_Entregadas  \
# 0                 65.598667              13.0                   2.0
# 1                 86.482222               9.0                   0.0
# 2                 63.196667              12.0                   2.0
# 3                 84.988333               8.0                   0.0
# 4                 68.542667              11.0                   3.0
# ...                     ...               ...                   ...
# 2494              71.818182               9.0                   2.0
# 2495              81.333333              15.0                   0.0
# 2496              73.333333               9.0                   0.0
# 2497              85.185556               9.0                   0.0
# 2498              80.159333              15.0                   0.0
#
#       Tareas_Retrasadas  Total_Tareas  Dias_Conectado  Minutos_Promedio  \
# 0                   0.0          15.0            32.0        370.231250
# 1                   0.0           9.0            50.0        198.717400
# 2                   1.0          15.0            22.0        294.535909
# 3                   4.0          12.0            29.0        471.421379
# 4                   1.0          15.0            31.0        306.023226
# ...                 ...           ...             ...               ...
# 2494                0.0          11.0            21.0        468.019048
# 2495                0.0          15.0            90.0        431.348000
# 2496                0.0           9.0            27.0        171.675926
# 2497                0.0           9.0           102.0        256.105686
# 2498                0.0          15.0            26.0        230.841538
#
#       Minutos_Total                                 materia
# 0          11847.40                  Liderazgo y Motivación
# 1           9935.87            Finanzas para no Financieros
# 2           6479.79                  Liderazgo y Motivación
# 3          13671.22           La Tecnología en la Educación
# 4           9486.72                  Liderazgo y Motivación
# ...             ...                                     ...
# 2494        9828.40                               Impuestos
# 2495       38821.32                        Redes Neuronales
# 2496        4635.25  Evaluación de Instituciones Educativos
# 2497       26122.78  Evaluación de Instituciones Educativos
# 2498        6001.88    Psicopatología y conductas de riesgo
#
# [2499 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(28, 4))

sns.distplot(df['Tareas_Puntuales'].dropna(), ax=axes[0])
sns.distplot(df['Tareas_No_Entregadas'].dropna(), ax=axes[1])
sns.distplot(df['Tareas_Retrasadas'].dropna(), ax=axes[2])
sns.distplot(df['Total_Tareas'].dropna(), ax=axes[3])
# Out:
# C:\Users\wm_herrera\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(28, 4))

sns.distplot(df['Dias_Conectado'].dropna(), ax=axes[0])
sns.distplot(df['Minutos_Promedio'].dropna(), ax=axes[1])
sns.distplot(df['Minutos_Total'].dropna(), ax=axes[2])

# %%
#df2 = df.drop(columns=['reducido','studentId','ciclo','Total_Tareas','Minutos_Promedio','Minutos_Total'], inplace=False)
df = df.drop(columns=['studentId'], inplace=False)

# %%
df.tail()
# Out:
#              reducido      ciclo Graduado  Calificacion_Promedio  \
# 2494        Adm. Emp.  2019 - 08       No              71.818182
# 2495            I. A.  2019 - 08       Si              81.333333
# 2496       Gest. Esc.  2019 - 08       No              73.333333
# 2497       Gest. Esc.  2019 - 08       Si              85.185556
# 2498  Psicopat. Adol.  2019 - 08       No              80.159333
#
#       Tareas_Puntuales  Tareas_No_Entregadas  Tareas_Retrasadas  Total_Tareas  \
# 2494               9.0                   2.0                0.0          11.0
# 2495              15.0                   0.0                0.0          15.0
# 2496               9.0                   0.0                0.0           9.0
# 2497               9.0                   0.0                0.0           9.0
# 2498              15.0                   0.0                0.0          15.0
#
#       Dias_Conectado  Minutos_Promedio  Minutos_Total  \
# 2494            21.0        468.019048        9828.40
# 2495            90.0        431.348000       38821.32
# 2496            27.0        171.675926        4635.25
# 2497           102.0        256.105686       26122.78
# 2498            26.0        230.841538        6001.88
#
#                                      materia
# 2494                               Impuestos
# 2495                        Redes Neuronales
# 2496  Evaluación de Instituciones Educativos
# 2497  Evaluación de Instituciones Educativos
# 2498    Psicopatología y conductas de riesgo

# %%
df.reducido.value_counts().sort_values(ascending=False).head(20)
# Out:
# Alim. Y Nut. Salud    263
# Direc. Proy.          154
# Educacion             132
# Est. Temprana         115
# Big Data               96
# Hab. Geren.            85
# E. Lectoescritura      79
# Mercadotecnia          68
# Planeacion Estrat.     66
# Lider. Inst. Edu.      64
# Comp. Directivas       62
# Intro. Fin             57
# Ventas Estrat.         56
# Admon Fin.             52
# Mkt. Digital           49
# Edu. Preescolar        46
# Neuromarketing         42
# Prof. Deportiva.       42
# Adm. Salud             42
# Coaching de Vida       39
# Name: reducido, dtype: int64

# %%
top10_r=[x for x in df.reducido.value_counts().sort_values(ascending=False).head(10).index]
top10_r=[]
top10_r
# Out:
# []

# %%
i=0
top10_rl=[]
for label in top10_r:
    i=i+1
    nlabel='red_'+str(i)
    top10_rl.append(nlabel)
    df[nlabel]=np.where(df.reducido==label,1,0)


#df[['reducido']+top10_rl].head(30)

df = df.drop(columns=['reducido'], inplace=False)

# %%
df.materia.value_counts().sort_values(ascending=False).head(20)
# Out:
# Liderazgo y Motivación                               148
# Ambiente y conductas obesogénicas                     69
# Planeación Estratégica                                65
# Contabilidad Financiera y Presupuestos                64
# Antecedentes y evolución de la alimentación           61
# Alimentación, crecimiento y desarrollo                58
# Big data y Business Analyitics                        54
# Composición corporal y metabolismo                    52
# Habilidades Sociales y Emocionales                    52
# Evaluación del Aprendizaje                            49
# Comunicación en Medios Digitales                      45
# Mercadotecnia Estratégica                             44
# Creativity Workshop: pensamiento lateral aplicado     44
# Trastornos de la conducta alimentaria (TCA)           43
# Marketing Analytics                                   42
# Trabajo en Equipo                                     40
# Gestión de las Adquisiciones                          39
# Creación y Evaluación de Materiales Didácticos        37
# Desarrollo emprendedor de negocios                    37
# Lenguaje                                              37
# Name: materia, dtype: int64

# %%
top10_m=[x for x in df.materia.value_counts().sort_values(ascending=False).head(10).index]
top10_m
# Out:
# ['Liderazgo y Motivación',
#  'Ambiente y conductas obesogénicas',
#  'Planeación Estratégica',
#  'Contabilidad Financiera y Presupuestos',
#  'Antecedentes y evolución de la alimentación',
#  'Alimentación, crecimiento y desarrollo',
#  'Big data y Business Analyitics',
#  'Composición corporal y metabolismo',
#  'Habilidades Sociales y Emocionales',
#  'Evaluación del Aprendizaje']

# %%
i=0
top10_ml=[]
for label in top10_m:
    i=i+1
    nlabel='mat_'+str(i)
    top10_ml.append(nlabel)
    df[nlabel]=np.where(df.materia==label,1,0)


#df[['materia']+top10_ml].head(30)

df = df.drop(columns=['materia'], inplace=False)

# %%
df.ciclo.value_counts().sort_values(ascending=False).head(20)
# Out:
# 2019 - 06    338
# 2019 - 07    334
# 2019 - 08    333
# 2019 - 05    280
# 2019 - 04    259
# 2019 - 03    160
# 2019 - 01    144
# 2019 - 02    128
# 2018 - 08     93
# 2018 - 07     58
# 2018 - 06     48
# 2018 - 02     44
# 2018 - 05     38
# 2017 - 07     35
# 2017 - 05     34
# 2018 - 03     30
# 2018 - 01     30
# 2018 - 04     28
# 2017 - 08     26
# 2017 - 06     22
# Name: ciclo, dtype: int64

# %%
top10_c=[x for x in df.ciclo.value_counts().sort_values(ascending=False).head(10).index]
top10_c=[]
top10_c
# Out:
# []

# %%
i=0
top10_cl=[]
for label in top10_c:
    i=i+1
    nlabel='cic_'+str(i)
    top10_cl.append(nlabel)
    df[nlabel]=np.where(df.ciclo==label,1,0)


#df[['ciclo']+top10_cl].head(30)

df = df.drop(columns=['ciclo'], inplace=False)

# %% [markdown]
# ### Manejando variables Categoricas
#
# Como se menciono antes, los computadores no son buenos con las variables categoricas.
#
# Mientras que nosotros entendemos bien las variables categoricas, es debido a un conocimiento previo quie el computador no tiene.
#
# La mayoria de tecnicas de Machine Learning y modelso trabajan con un set limitado de datos (Tipicamente binario).
#
# Las redes neurales consumenda data y producen resultados en el rango de 0..1 t raramente van mas alla del alcance.
#
# En resumen, la gran mayoria de algoritmos de machine learning aceptan data de entrada  ("training data") de donde los features son extraidos.
#
# Basado en estos features, un modelo matematico es creado, el cual es usado para hacer una predicción o decision sin ser programado explicitamente para esa tarea.
#
# Dado un dataset con con 2 features, vamos a dejar que encoder encuentre los valores unicos por features y transforme la data a binario usando la tecnica one-hot encoding.

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

#df2['Graduado'] = le.fit_transform(df2['Graduado'])
#df2['reducido'] = le.fit_transform(df2['reducido'])
#df2['ciclo'] = le.fit_transform(df2['ciclo'])
#df2['materia'] = le.fit_transform(df2['materia'])


df3 = df;
df3.tail()
# Out:
#      Graduado  Calificacion_Promedio  Tareas_Puntuales  Tareas_No_Entregadas  \
# 2494       No              71.818182               9.0                   2.0
# 2495       Si              81.333333              15.0                   0.0
# 2496       No              73.333333               9.0                   0.0
# 2497       Si              85.185556               9.0                   0.0
# 2498       No              80.159333              15.0                   0.0
#
#       Tareas_Retrasadas  Total_Tareas  Dias_Conectado  Minutos_Promedio  \
# 2494                0.0          11.0            21.0        468.019048
# 2495                0.0          15.0            90.0        431.348000
# 2496                0.0           9.0            27.0        171.675926
# 2497                0.0           9.0           102.0        256.105686
# 2498                0.0          15.0            26.0        230.841538
#
#       Minutos_Total  mat_1  mat_2  mat_3  mat_4  mat_5  mat_6  mat_7  mat_8  \
# 2494        9828.40      0      0      0      0      0      0      0      0
# 2495       38821.32      0      0      0      0      0      0      0      0
# 2496        4635.25      0      0      0      0      0      0      0      0
# 2497       26122.78      0      0      0      0      0      0      0      0
# 2498        6001.88      0      0      0      0      0      0      0      0
#
#       mat_9  mat_10
# 2494      0       0
# 2495      0       0
# 2496      0       0
# 2497      0       0
# 2498      0       0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 8))

sns.countplot(ax=axes[0], x='Graduado', data=df3)
plt.show()

# %% [markdown]
# <hr>

# %% [markdown]
# ## Entrenando un clasificador basado  en un Árbol de Decisión

# %% [markdown]
# ### Seleccionando FEATURES y definiendo la variable TARGET

# %%
df3.columns
# Out:
# Index(['Graduado', 'Calificacion_Promedio', 'Tareas_Puntuales',
#        'Tareas_No_Entregadas', 'Tareas_Retrasadas', 'Total_Tareas',
#        'Dias_Conectado', 'Minutos_Promedio', 'Minutos_Total', 'mat_1', 'mat_2',
#        'mat_3', 'mat_4', 'mat_5', 'mat_6', 'mat_7', 'mat_8', 'mat_9',
#        'mat_10'],
#       dtype='object')

# %%
features = df3[
 
      ['Calificacion_Promedio',
       'Tareas_Puntuales', 'Tareas_No_Entregadas',
       'Tareas_Retrasadas',
       'Total_Tareas', 
       'Dias_Conectado', 'Minutos_Promedio', 'Minutos_Total'
      ]+
    top10_rl+top10_cl+top10_ml
 
]
target = df3['Graduado']  ## No cambie la variable target!

# %% [markdown]
# ### Dividiendo nuestro dataset en set de Entrenamiento y Pruebas

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=133)

# %%
X_train
# Out:
#       Calificacion_Promedio  Tareas_Puntuales  Tareas_No_Entregadas  \
# 109               91.852222               9.0                   0.0
# 1107              89.778000              14.0                   0.0
# 1862              86.667143              13.0                   1.0
# 1946              93.000000              10.0                   0.0
# 1541              76.295556               9.0                   0.0
# ...                     ...               ...                   ...
# 1277              71.136364              11.0                   0.0
# 564               10.000000               1.0                   8.0
# 1900              61.250000               5.0                   3.0
# 1025              95.404000               5.0                   0.0
# 1080               0.000000               1.0                  11.0
#
#       Tareas_Retrasadas  Total_Tareas  Dias_Conectado  Minutos_Promedio  \
# 109                 0.0           9.0            47.0        145.522766
# 1107                1.0          15.0            41.0        412.001707
# 1862                0.0          14.0            49.0        330.033061
# 1946                0.0          10.0            78.0        125.063462
# 1541                0.0           9.0            86.0        165.728605
# ...                 ...           ...             ...               ...
# 1277                0.0          11.0            61.0        259.390984
# 564                 0.0           9.0             3.0        173.326667
# 1900                0.0           8.0            11.0        365.504545
# 1025                0.0           5.0            29.0        273.259655
# 1080                0.0          12.0             4.0          7.647500
#
#       Minutos_Total  mat_1  mat_2  mat_3  mat_4  mat_5  mat_6  mat_7  mat_8  \
# 109         6839.57      0      0      0      0      0      0      0      0
# 1107       16892.07      0      0      0      0      0      0      0      1
# 1862       16171.62      0      0      0      0      0      1      0      0
# 1946        9754.95      0      0      0      0      0      0      0      0
# 1541       14252.66      0      0      0      0      0      0      0      0
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1277       15822.85      0      0      0      0      0      0      0      0
# 564          519.98      0      0      0      0      0      0      0      0
# 1900        4020.55      0      0      0      0      0      0      0      0
# 1025        7924.53      0      0      0      0      0      0      0      0
# 1080          30.59      0      0      0      0      0      0      0      0
#
#       mat_9  mat_10
# 109       0       0
# 1107      0       0
# 1862      0       0
# 1946      0       0
# 1541      0       0
# ...     ...     ...
# 1277      0       0
# 564       0       0
# 1900      0       0
# 1025      0       0
# 1080      0       0
#
# [1999 rows x 18 columns]

# %%
X_test
# Out:
#       Calificacion_Promedio  Tareas_Puntuales  Tareas_No_Entregadas  \
# 1555              90.952857              14.0                   0.0
# 915               85.925556               8.0                   1.0
# 210                0.000000               0.0                   8.0
# 829               79.814444               8.0                   1.0
# 47                97.500000               8.0                   0.0
# ...                     ...               ...                   ...
# 2093              83.700000              10.0                   0.0
# 1330              91.777333              15.0                   0.0
# 1998              93.666000              10.0                   0.0
# 393               90.909091              10.0                   1.0
# 385               94.814444               9.0                   0.0
#
#       Tareas_Retrasadas  Total_Tareas  Dias_Conectado  Minutos_Promedio  \
# 1555                0.0          14.0            87.0        175.953218
# 915                 0.0           9.0            33.0        214.765758
# 210                 1.0           9.0             1.0         25.060000
# 829                 0.0           9.0            40.0        509.833000
# 47                  0.0           8.0            31.0        223.734839
# ...                 ...           ...             ...               ...
# 2093                0.0          10.0            50.0        176.201800
# 1330                0.0          15.0            70.0        219.270429
# 1998                0.0          10.0            88.0        279.133636
# 393                 0.0          11.0            54.0        388.147222
# 385                 0.0           9.0           122.0        178.242623
#
#       Minutos_Total  mat_1  mat_2  mat_3  mat_4  mat_5  mat_6  mat_7  mat_8  \
# 1555       15307.93      0      0      0      0      0      1      0      0
# 915         7087.27      0      0      0      0      0      0      0      0
# 210           25.06      0      0      0      0      0      0      0      0
# 829        20393.32      0      0      0      0      0      0      0      0
# 47          6935.78      0      0      0      0      0      0      0      0
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2093        8810.09      0      0      0      0      0      0      0      0
# 1330       15348.93      0      0      0      0      0      0      0      0
# 1998       24563.76      1      0      0      0      0      0      0      0
# 393        20959.95      0      0      0      0      0      0      0      0
# 385        21745.60      0      0      0      0      0      0      0      0
#
#       mat_9  mat_10
# 1555      0       0
# 915       0       0
# 210       0       0
# 829       0       0
# 47        0       0
# ...     ...     ...
# 2093      0       0
# 1330      0       0
# 1998      0       0
# 393       0       0
# 385       0       0
#
# [500 rows x 18 columns]

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train_std=sc.fit_transform(X_train)
X_test_std=sc.transform(X_test)

 
    

from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler()

X_train_std_min_max=sc.fit_transform(X_train)
X_test_std_min_max=sc.transform(X_test) 


from sklearn.preprocessing import MaxAbsScaler
 
sc = MaxAbsScaler()

X_train_std_max_abs=sc.fit_transform(X_train)
X_test_std_max_abs=sc.transform(X_test) 

from sklearn.preprocessing import RobustScaler
 
sc = RobustScaler(quantile_range=(25, 75))

X_train_std_rb =sc.fit_transform(X_train)
X_test_std_rb =sc.transform(X_test)

# %%
X_train_std_rb
# Out:
# array([[ 0.37495954,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.2922601 ,  1.25      ,  0.        , ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.16822991,  1.        ,  0.5       , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-0.8451541 , -1.        ,  1.5       , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.51656928, -1.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-3.28719769, -2.        ,  5.5       , ...,  0.        ,
#          0.        ,  0.        ]])

# %% [markdown]
# ### Entrenando un modelo ``DecisionTreeClassifier()``

# %%
# Método para creacion de modelos basados en arbol de desición
from sklearn.tree import DecisionTreeClassifier


dtc = DecisionTreeClassifier(max_depth=15).fit(X_train, y_train)

# %% [markdown]
# ### Haciendo predicciones del Sample Test

# %%
y_pred = dtc.predict(X_test)
print(y_pred)
# Out:
# ['Si' 'No' 'No' 'No' 'Si' 'No' 'No' 'Si' 'Si' 'No' 'No' 'No' 'No' 'No'
#  'No' 'Si' 'No' 'No' 'No' 'No' 'No' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'Si'
#  'Si' 'No' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'No' 'No' 'Si'
#  'Si' 'No' 'Si' 'No' 'Si' 'No' 'No' 'No' 'Si' 'No' 'No' 'Si' 'No' 'Si'
#  'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si'
#  'Si' 'No' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'No'
#  'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'No' 'No'
#  'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'No' 'No' 'No' 'Si' 'Si'
#  'Si' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'No'
#  'No' 'Si' 'No' 'Si' 'No' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si'
#  'Si' 'No' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'No'
#  'No' 'No' 'Si' 'No' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'No' 'No'
#  'No' 'No' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'No'
#  'Si' 'Si' 'No' 'Si' 'No' 'No' 'Si' 'No' 'No' 'Si' 'No' 'No' 'Si' 'No'
#  'No' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'No'
#  'Si' 'No' 'Si' 'Si' 'No' 'No' 'No' 'No' 'Si' 'No' 'No' 'Si' 'No' 'No'
#  'No' 'Si' 'Si' 'Si' 'No' 'No' 'No' 'Si' 'No' 'No' 'No' 'No' 'Si' 'Si'
#  'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'Si' 'No'
#  'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'No' 'Si' 'Si'
#  'Si' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'Si' 'Si' 'No'
#  'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'No'
#  'No' 'No' 'Si' 'No' 'No' 'No' 'Si' 'No' 'Si' 'Si' 'Si' 'No' 'No' 'No'
#  'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'No' 'Si'
#  'No' 'Si' 'No' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si'
#  'No' 'Si' 'No' 'Si' 'No' 'No' 'No' 'No' 'Si' 'No' 'No' 'Si' 'Si' 'Si'
#  'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si'
#  'No' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'No' 'No' 'Si'
#  'Si' 'No' 'No' 'No' 'No' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No'
#  'Si' 'No' 'No' 'No' 'No' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'Si'
#  'No' 'Si' 'No' 'No' 'Si' 'No' 'No' 'No' 'Si' 'No' 'Si' 'No' 'Si' 'Si'
#  'Si' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'Si'
#  'No' 'No' 'No' 'Si' 'No' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'No' 'No' 'No'
#  'No' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'No'
#  'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'Si' 'No' 'Si'
#  'No' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'No'
#  'No' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'Si']

# %% [markdown]
# ### Analice la calidad del modelo a través de la matriz de confusión

# %%
from sklearn.metrics import confusion_matrix



cf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['`Positivo` Correto', '`Negativo` Errado', 'Falso `Positivo`', '`Negativo` Correto']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2,2)
accuracy  = np.trace(cf_matrix) / float(np.sum(cf_matrix))
precision = cf_matrix[1,1] / sum(cf_matrix[:,1])
recall    = cf_matrix[1,1] / sum(cf_matrix[1,:])
f1_score  = 2*precision*recall / (precision + recall)
sns.heatmap(cf_matrix, annot=labels, fmt="")
stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={}".format(accuracy, precision, recall, f1_score)
plt.ylabel('True label')
plt.xlabel('Predicted label' + stats_text)
# Out:
# Text(0.5, 15.0, 'Predicted label\n\nAccuracy=0.738\nPrecision=0.748\nRecall=0.751\nF1 Score=0.7495219885277247')

# %%
correlation = df3.corr()
plt.figure(figsize=(100, 100))
sns.heatmap(correlation, fmt='.1g', vmax=1, square=True, annot=True,cmap='coolwarm')

plt.show()

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
x_train=X_train
x_test=X_test 

from sklearn.ensemble import RandomForestClassifier
clf =RandomForestClassifier(n_estimators=150, random_state=0,criterion='entropy',max_depth=8)
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)
print(classification_report(y_test, predictions))

print("Exactitud RandomForestClassifier 1: {}%".format(100*round(accuracy_score(y_test, predictions), 6)))



y_pred = predictions

from sklearn.metrics import confusion_matrix

cf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['Aprobado `Aceptado`', 'Refused `Sospechoso`', 'Refused `Aceptado`', 'Aprobado `Sospechoso`']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2,2)
accuracy  = np.trace(cf_matrix) / float(np.sum(cf_matrix))
precision = cf_matrix[1,1] / sum(cf_matrix[:,1])
recall    = cf_matrix[1,1] / sum(cf_matrix[1,:])
f1_score  = 2*precision*recall / (precision + recall)
sns.heatmap(cf_matrix, annot=labels, fmt='')
stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={}".format(accuracy, precision, recall, f1_score)
plt.ylabel('True label RandomForestClassifier 1')
plt.xlabel('Predicted label' + stats_text)
plt.show() 

# get importance
importance = clf.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()

print("Features sorted by their score:")
print(sorted(zip(map(lambda x: round(x, 4), clf.feature_importances_), features), reverse=True))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.84      0.75      0.79       239
#           Si       0.79      0.87      0.83       261
#
#     accuracy                           0.81       500
#    macro avg       0.82      0.81      0.81       500
# weighted avg       0.81      0.81      0.81       500
#
# Exactitud RandomForestClassifier 1: 81.2%
# Feature: 0, Score: 0.22901
# Feature: 1, Score: 0.09225
# Feature: 2, Score: 0.12261
# Feature: 3, Score: 0.01135
# Feature: 4, Score: 0.02446
# Feature: 5, Score: 0.28972
# Feature: 6, Score: 0.07290
# Feature: 7, Score: 0.13008
# Feature: 8, Score: 0.00257
# Feature: 9, Score: 0.00190
# Feature: 10, Score: 0.00826
# Feature: 11, Score: 0.00149
# Feature: 12, Score: 0.00296
# Feature: 13, Score: 0.00157
# Feature: 14, Score: 0.00174
# Feature: 15, Score: 0.00180
# Feature: 16, Score: 0.00305
# Feature: 17, Score: 0.00226
# Features sorted by their score:
# [(0.2897, 'Dias_Conectado'), (0.229, 'Calificacion_Promedio'), (0.1301, 'Minutos_Total'), (0.1226, 'Tareas_No_Entregadas'), (0.0923, 'Tareas_Puntuales'), (0.0729, 'Minutos_Promedio'), (0.0245, 'Total_Tareas'), (0.0114, 'Tareas_Retrasadas'), (0.0083, 'mat_3'), (0.0031, 'mat_9'), (0.003, 'mat_5'), (0.0026, 'mat_1'), (0.0023, 'mat_10'), (0.0019, 'mat_2'), (0.0018, 'mat_8'), (0.0017, 'mat_7'), (0.0016, 'mat_6'), (0.0015, 'mat_4')]

# %%
x_train=X_train
x_test=X_test
from sklearn.metrics import accuracy_score

from sklearn.ensemble import GradientBoostingClassifier
dtc=GradientBoostingClassifier(max_depth=4, n_estimators=100)
dtc.fit(x_train, y_train)
predictions = dtc.predict(x_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))

print("Exactitud GradientBoostingClassifier tunning: {}%".format(100*round(accuracy_score(y_test, predictions), 6)))

y_pred = predictions

from sklearn.metrics import confusion_matrix

cf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['Aprobado `Aceptado`', 'Refused `Sospechoso`', 'Refused `Aceptado`', 'Aprobado `Sospechoso`']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2,2)
accuracy  = np.trace(cf_matrix) / float(np.sum(cf_matrix))
precision = cf_matrix[1,1] / sum(cf_matrix[:,1])
recall    = cf_matrix[1,1] / sum(cf_matrix[1,:])
f1_score  = 2*precision*recall / (precision + recall)
sns.heatmap(cf_matrix, annot=labels, fmt='')
stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={}".format(accuracy, precision, recall, f1_score)
plt.ylabel('True label GradientBoostingClassifier tunning')
plt.xlabel('Predicted label' + stats_text)
plt.show()


# get importance
importance = dtc.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()

print("Features sorted by their score:")
print(sorted(zip(map(lambda x: round(x, 4), dtc.feature_importances_), features), reverse=True))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.83      0.80      0.81       239
#           Si       0.82      0.85      0.83       261
#
#     accuracy                           0.82       500
#    macro avg       0.82      0.82      0.82       500
# weighted avg       0.82      0.82      0.82       500
#
# Exactitud GradientBoostingClassifier tunning: 82.39999999999999%
# Feature: 0, Score: 0.24262
# Feature: 1, Score: 0.03495
# Feature: 2, Score: 0.00812
# Feature: 3, Score: 0.00291
# Feature: 4, Score: 0.01573
# Feature: 5, Score: 0.54875
# Feature: 6, Score: 0.07131
# Feature: 7, Score: 0.04660
# Feature: 8, Score: 0.00235
# Feature: 9, Score: 0.00188
# Feature: 10, Score: 0.01167
# Feature: 11, Score: 0.00071
# Feature: 12, Score: 0.00172
# Feature: 13, Score: 0.00137
# Feature: 14, Score: 0.00240
# Feature: 15, Score: 0.00155
# Feature: 16, Score: 0.00389
# Feature: 17, Score: 0.00147
# Features sorted by their score:
# [(0.5488, 'Dias_Conectado'), (0.2426, 'Calificacion_Promedio'), (0.0713, 'Minutos_Promedio'), (0.0466, 'Minutos_Total'), (0.035, 'Tareas_Puntuales'), (0.0157, 'Total_Tareas'), (0.0117, 'mat_3'), (0.0081, 'Tareas_No_Entregadas'), (0.0039, 'mat_9'), (0.0029, 'Tareas_Retrasadas'), (0.0024, 'mat_7'), (0.0023, 'mat_1'), (0.0019, 'mat_2'), (0.0017, 'mat_5'), (0.0015, 'mat_8'), (0.0015, 'mat_10'), (0.0014, 'mat_6'), (0.0007, 'mat_4')]

# %%
x_train=X_train
x_test=X_test 


from xgboost import XGBClassifier

clf =XGBClassifier(objective='binary:logistic',max_depth=4)
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)

y_pred = predictions
 
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("Exactitud XGBClassifier: {}%".format(100*round(accuracy_score(y_test, y_pred), 6)))


y_pred = predictions

from sklearn.metrics import confusion_matrix

cf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['Aprobado `Aceptado`', 'Refused `Sospechoso`', 'Refused `Aceptado`', 'Aprobado `Sospechoso`']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2,2)
accuracy  = np.trace(cf_matrix) / float(np.sum(cf_matrix))
precision = cf_matrix[1,1] / sum(cf_matrix[:,1])
recall    = cf_matrix[1,1] / sum(cf_matrix[1,:])
f1_score  = 2*precision*recall / (precision + recall)
sns.heatmap(cf_matrix, annot=labels, fmt='')
stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={}".format(accuracy, precision, recall, f1_score)
plt.ylabel('True label XGBClassifier')
plt.xlabel('Predicted label' + stats_text)
plt.show()



# get importance
importance = clf.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()

print("Features sorted by their score:")
print(sorted(zip(map(lambda x: round(x, 4), clf.feature_importances_), features), reverse=True))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.78      0.78      0.78       239
#           Si       0.80      0.80      0.80       261
#
#     accuracy                           0.79       500
#    macro avg       0.79      0.79      0.79       500
# weighted avg       0.79      0.79      0.79       500
#
# Exactitud XGBClassifier: 79.0%
# Feature: 0, Score: 0.07988
# Feature: 1, Score: 0.05573
# Feature: 2, Score: 0.03803
# Feature: 3, Score: 0.03888
# Feature: 4, Score: 0.03339
# Feature: 5, Score: 0.21037
# Feature: 6, Score: 0.03441
# Feature: 7, Score: 0.03764
# Feature: 8, Score: 0.10364
# Feature: 9, Score: 0.03584
# Feature: 10, Score: 0.07804
# Feature: 11, Score: 0.01287
# Feature: 12, Score: 0.03444
# Feature: 13, Score: 0.06806
# Feature: 14, Score: 0.03842
# Feature: 15, Score: 0.01932
# Feature: 16, Score: 0.05475
# Feature: 17, Score: 0.02628
# Features sorted by their score:
# [(0.2104, 'Dias_Conectado'), (0.1036, 'mat_1'), (0.0799, 'Calificacion_Promedio'), (0.078, 'mat_3'), (0.0681, 'mat_6'), (0.0557, 'Tareas_Puntuales'), (0.0547, 'mat_9'), (0.0389, 'Tareas_Retrasadas'), (0.0384, 'mat_7'), (0.038, 'Tareas_No_Entregadas'), (0.0376, 'Minutos_Total'), (0.0358, 'mat_2'), (0.0344, 'mat_5'), (0.0344, 'Minutos_Promedio'), (0.0334, 'Total_Tareas'), (0.0263, 'mat_10'), (0.0193, 'mat_8'), (0.0129, 'mat_4')]

# %%
x_train=X_train
x_test=X_test 

from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.ensemble import HistGradientBoostingClassifier

clf =HistGradientBoostingClassifier(loss='binary_crossentropy',max_depth=10)
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)

y_pred = predictions
 
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("Exactitud HistGradientBoostingClassifier: {}%".format(100*round(accuracy_score(y_test, y_pred), 6)))

 


y_pred = predictions

from sklearn.metrics import confusion_matrix

cf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['Aprobado `Aceptado`', 'Refused `Sospechoso`', 'Refused `Aceptado`', 'Aprobado `Sospechoso`']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2,2)
accuracy  = np.trace(cf_matrix) / float(np.sum(cf_matrix))
precision = cf_matrix[1,1] / sum(cf_matrix[:,1])
recall    = cf_matrix[1,1] / sum(cf_matrix[1,:])
f1_score  = 2*precision*recall / (precision + recall)
sns.heatmap(cf_matrix, annot=labels, fmt='')
stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={}".format(accuracy, precision, recall, f1_score)
plt.ylabel('True label HistGradientBoostingClassifier 2')
plt.xlabel('Predicted label' + stats_text)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#           No       0.81      0.79      0.80       239
#           Si       0.81      0.83      0.82       261
#
#     accuracy                           0.81       500
#    macro avg       0.81      0.81      0.81       500
# weighted avg       0.81      0.81      0.81       500
#
# Exactitud HistGradientBoostingClassifier: 81.0%

# %%
mnn


x_train=X_train
x_test=X_test 

from sklearn import svm

clf = svm.SVC()
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)

y_pred = predictions
 
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("Exactitud SVC: {}%".format(100*round(accuracy_score(y_test, y_pred), 6)))

 


y_pred = predictions

from sklearn.metrics import confusion_matrix

cf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['Aprobado `Aceptado`', 'Refused `Sospechoso`', 'Refused `Aceptado`', 'Aprobado `Sospechoso`']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2,2)
accuracy  = np.trace(cf_matrix) / float(np.sum(cf_matrix))
precision = cf_matrix[1,1] / sum(cf_matrix[:,1])
recall    = cf_matrix[1,1] / sum(cf_matrix[1,:])
f1_score  = 2*precision*recall / (precision + recall)
sns.heatmap(cf_matrix, annot=labels, fmt='')
stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={}".format(accuracy, precision, recall, f1_score)
plt.ylabel('True label SVC ')
plt.xlabel('Predicted label' + stats_text)
plt.show()

# %%
 

#clf = svm.SVC(kernel='linear',coef0=1.6,decision_function_shape='ovr',degree=0,gamma=4)

x_train=X_train_std
x_test=X_test_std 

from sklearn import svm

clf = svm.SVC(kernel='sigmoid')
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)

y_pred = predictions
 
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("Exactitud SVC: {}%".format(100*round(accuracy_score(y_test, y_pred), 6)))

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PowerTransformer
sc = PowerTransformer(method='yeo-johnson')
sc=PowerTransformer(method='box-cox')
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler
 

sc = MinMaxScaler() #81.2%
sc =Normalizer() # 80.0%
sc = QuantileTransformer(output_distribution='uniform') #82.0%
sc = QuantileTransformer(output_distribution='normal') #80.8% no converge
sc = PowerTransformer(method='yeo-johnson') #81.8



sc = RobustScaler(quantile_range=(25, 75)) #80.60 no converge
sc = StandardScaler()  #80.6 no converge
sc = MaxAbsScaler() #81.2


 #82.0%

sc = MinMaxScaler()
sc = StandardScaler() 
sc = PowerTransformer(method='yeo-johnson')

sc = QuantileTransformer(output_distribution='uniform')

X_train_t=sc.fit_transform(X_train)
X_test_t=sc.transform(X_test) 


x_train=X_train_t
x_test=X_test_t

from sklearn import svm

clf = svm.LinearSVC()
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)

y_pred = predictions
 
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("Exactitud SVC: {}%".format(100*round(accuracy_score(y_test, y_pred), 6)))

# %%
sc = QuantileTransformer(output_distribution='uniform') #83




X_train_t=sc.fit_transform(X_train)
X_test_t=sc.transform(X_test) 

x_train=X_train_t
x_test=X_test_t 

from sklearn import svm

clf = svm.SVC(kernel='poly')
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)

y_pred = predictions
 
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("Exactitud SVC: {}%".format(100*round(accuracy_score(y_test, y_pred), 6)))

# %%
sc = QuantileTransformer(output_distribution='uniform') #83




X_train_t=sc.fit_transform(X_train)
X_test_t=sc.transform(X_test) 

x_train=X_train_t
x_test=X_test_t 



from sklearn import svm

clf = svm.SVC(kernel='sigmoid')
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)

y_pred = predictions
 
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("Exactitud SVC: {}%".format(100*round(accuracy_score(y_test, y_pred), 6)))

# %%
sc = QuantileTransformer(output_distribution='uniform') #83




X_train_t=sc.fit_transform(X_train)
X_test_t=sc.transform(X_test) 

x_train=X_train_t
x_test=X_test_t 


from sklearn import svm

clf = svm.SVC(kernel='linear',gamma='auto')
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)

y_pred = predictions
 
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("Exactitud SVC: {}%".format(100*round(accuracy_score(y_test, y_pred), 6)))

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PowerTransformer
sc = PowerTransformer(method='yeo-johnson')
sc=PowerTransformer(method='box-cox')
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler
 

sc = MinMaxScaler() #81.2%
sc =Normalizer() # 80.0%
sc = QuantileTransformer(output_distribution='uniform') #82.0%
sc = QuantileTransformer(output_distribution='normal') #80.8% no converge
sc = PowerTransformer(method='yeo-johnson') #81.8



sc = RobustScaler(quantile_range=(25, 75)) #80.60 no converge
sc = StandardScaler()  #80.6 no converge
sc = MaxAbsScaler() #81.2

X_train_t=sc.fit_transform(X_train)
X_test_t=sc.transform(X_test) 

sc = QuantileTransformer(output_distribution='uniform') #82.0%
sc = MinMaxScaler()
sc = RobustScaler(quantile_range=(25, 75))
sc = MinMaxScaler()
sc = QuantileTransformer(output_distribution='uniform')

sc = MaxAbsScaler()
sc = PowerTransformer(method='yeo-johnson')
sc =Normalizer() 

sc = MinMaxScaler() #82.19 
sc = StandardScaler()
sc = QuantileTransformer(output_distribution='uniform')
sc = StandardScaler()

sc = PowerTransformer(method='yeo-johnson')
sc = StandardScaler()
sc = QuantileTransformer(output_distribution='uniform')

X_train_t=sc.fit_transform(X_train)
X_test_t=sc.transform(X_test) 

x_train=X_train_t
x_test=X_test_t

from sklearn.naive_bayes import GaussianNB

from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier

# Initialize our classifier
clf =   MLPClassifier(solver='adam',max_iter=400)
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)

y_pred = predictions
 
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("Exactitud SVC: {}%".format(100*round(accuracy_score(y_test, y_pred), 6)))
clf

# %%
sc = PowerTransformer(method='yeo-johnson')
sc = StandardScaler()
sc = QuantileTransformer(output_distribution='uniform')

X_train_t=sc.fit_transform(X_train)
X_test_t=sc.transform(X_test) 

x_train=X_train_t
x_test=X_test_t

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal, uniform

clf = LogisticRegression()
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)

y_pred = predictions
 
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("Exactitud SVC: {}%".format(100*round(accuracy_score(y_test, y_pred), 6)))

# %%
x_train=X_train_std
x_test=X_test_std 

from sklearn import svm

from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal, uniform

logistic = svm.SVC(C=3.3,coef0=2.1)
distributions = dict(
    coef0=uniform(loc=0, scale=3),
    kernel=['linear'],
    gamma = [1,2,3,4,5],
    decision_function_shape=['ovo','ovr'],
    degree=[0, 1, 2, 3, 4, 5, 6]
    
)
clf = RandomizedSearchCV(logistic, distributions, random_state=0)
search = clf.fit(x_train, y_train)

search.best_score_

# %%
search.best_params_

#{'coef0': 2.195254015709299, 'gamma': 1, 'kernel': 'linear'}

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal, uniform

logistic = LogisticRegression(solver='saga', tol=1e-2, max_iter=200,random_state=0)
distributions = dict(C=uniform(loc=0, scale=4), penalty=['l2', 'l1'])
clf = RandomizedSearchCV(logistic, distributions, random_state=0)
search = clf.fit(x_train, y_train)
search.best_params_
search.best_score_

# %% [markdown]
# <hr>

# %% [markdown]
# ## Scoring de la data requerida para hacer la entrega de la solución

# %% [markdown]
# Para el envío, necesita clasificar el siguiente dataset. Para hacer eso, usted necesita reproducir los mismos pasos de pre-procesamiento para que el dataset este en la misma estructura del que usted uso para construir su modelo. Despues de clasificar este dataframe, esperamos que usted entregue un archivo csv con las 2499 filar y una columna 'Graduado' con su predicción. **No cambie el orden del archivo a predecir ni borre filas**

# %%
# !wget --no-check-certificate --content-disposition https://raw.githubusercontent.com/vanderlei-test/dataset2/master/for_submission/ToBePredicted.csv
df_to_be_predicted = pd.read_csv(r'ToBePredicted.csv')
df_to_be_predicted.tail()

# %%
# Uniendo los dataset
df = pd.merge(
    df_to_be_predicted, df_tabla_tareas, how='inner',
    on=None, left_on=['studentId', 'ciclo'], right_on=['studentId', 'ciclo'],
    left_index=False, right_index=False, sort=True,
    suffixes=('_x', '_y'), copy=True, indicator=False,
    validate=None
)

# Eliminando la columna 'reducido'
df2 = df.drop(columns=['reducido'], inplace=False)

# Columnas One-hot-encoding del dataset usando el metodo de Pandas ``get_dummies``  (demontración)
df3 = pd.get_dummies(df2, columns=['ciclo'])
df3.tail()

# %% [markdown]
# Observando los features declarados acontinuación, sabemos que el dataset ha ser evaluado esta en el mismo formato usado para entrenar nuestro árbol de decisión anteriormente.
#
# ```features = df3[
#     [
#         'studentId', 'Calificacion_Promedio', 'Tareas_Puntuales',
#         'Tareas_No_Entregadas', 'Tareas_Retrasadas', 'Total_Tareas',
#         'ciclo_2017 - 03', 'ciclo_2017 - 04', 'ciclo_2017 - 05',
#         'ciclo_2017 - 06', 'ciclo_2017 - 07', 'ciclo_2017 - 08',
#         'ciclo_2018 - 01', 'ciclo_2018 - 02', 'ciclo_2018 - 03',
#         'ciclo_2018 - 04', 'ciclo_2018 - 05', 'ciclo_2018 - 06',
#         'ciclo_2018 - 07', 'ciclo_2018 - 08', 'ciclo_2019 - 01',
#         'ciclo_2019 - 02', 'ciclo_2019 - 03', 'ciclo_2019 - 04',
#         'ciclo_2019 - 05', 'ciclo_2019 - 06', 'ciclo_2019 - 07',
#         'ciclo_2019 - 08'
#     ]
# ]
# target = df3['Graduado']  ## No cambie la variable target!```

# %%
y_pred = dtc.predict(df3[
    [
        'studentId', 'Calificacion_Promedio', 'Tareas_Puntuales',
        'Tareas_No_Entregadas', 'Tareas_Retrasadas', 'Total_Tareas',
        'ciclo_2017 - 03', 'ciclo_2017 - 04', 'ciclo_2017 - 05',
        'ciclo_2017 - 06', 'ciclo_2017 - 07', 'ciclo_2017 - 08',
        'ciclo_2018 - 01', 'ciclo_2018 - 02', 'ciclo_2018 - 03',
        'ciclo_2018 - 04', 'ciclo_2018 - 05', 'ciclo_2018 - 06',
        'ciclo_2018 - 07', 'ciclo_2018 - 08', 'ciclo_2019 - 01',
        'ciclo_2019 - 02', 'ciclo_2019 - 03', 'ciclo_2019 - 04',
        'ciclo_2019 - 05', 'ciclo_2019 - 06', 'ciclo_2019 - 07',
        'ciclo_2019 - 08'
    ]
])
print(y_pred)

# %% [markdown]
# ### Guardando los resultados de la predicción en un archivo csv

# %%
np.savetxt("results.csv", y_pred, delimiter=",", fmt='%s')

# %%
project.save_data(file_name="results.csv", data=pd.read_csv("results.csv", header=None).to_csv(header=["TARGET"], index=False))

# %% [markdown]
# <hr>
#
# ## ¡Felicitaciones!
#
# Si todo fue ejecutado sin errores, usted ya tiene un modelo basado en classificacion binaria y puede descargar sus resultados para subirlos como csv!
#
# Para enviar su solución, ve a la página:
#
# # https://anahuac.maratona.dev
